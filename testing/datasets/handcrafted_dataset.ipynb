# %%
import sys
sys.path.append("../../")
import pathlib
working_directory = pathlib.Path().absolute()
sys.path.append(str(working_directory))
from pyadlml.dataset import set_data_home, load_act_assist

SUBJECT_NAME = 'test'
dataset_dir = str(working_directory) + '/handcrafted_dataset'
data = load_act_assist(dataset_dir,subjects=[SUBJECT_NAME])
data.df_activities = data.df_activities_test
# Out:
# went into correction
# went out of correction

# %%
data.df_activities
# Out:
#                start_time            end_time    activity
# 0 2000-01-01 00:00:00.000 2000-01-01 00:00:20  activity_1
# 1 2000-01-01 00:00:20.010 2000-01-01 00:00:40  activity_2
# 2 2000-01-01 00:00:40.010 2000-01-01 00:01:00  activity_3

# %%
data.df_devices
# Out:
#                       time  device      value
# 0  2000-01-01 00:00:00.000   num_1      3.143
# 1  2000-01-01 00:00:00.010   cat_1  sub_cat_1
# 2  2000-01-01 00:00:00.020  bool_3      False
# 3  2000-01-01 00:00:00.030   cat_2  sub_cat_1
# 4  2000-01-01 00:00:10.000   cat_2  sub_cat_2
# 5  2000-01-01 00:00:10.010  bool_2       True
# 6  2000-01-01 00:00:10.020  bool_1      False
# 7  2000-01-01 00:00:10.030   num_1      2.143
# 8  2000-01-01 00:00:20.000  bool_1       True
# 9  2000-01-01 00:00:20.010  bool_2      False
# 10 2000-01-01 00:00:20.020   num_1      1.143
# 11 2000-01-01 00:00:30.000  bool_2       True
# 12 2000-01-01 00:00:30.010  bool_3       True
# 13 2000-01-01 00:00:30.020   num_1      4.143
# 14 2000-01-01 00:00:30.030  bool_1      False
# 15 2000-01-01 00:00:40.000   cat_1  sub_cat_2
# 16 2000-01-01 00:00:40.010   num_1      5.143
# 17 2000-01-01 00:00:40.020   cat_2  sub_cat_3
# 18 2000-01-01 00:00:50.000   num_1      6.143
# ...

# %% [markdown]
# # Activities

# %%
from pyadlml.dataset.plot.activities import (
    counts as plot_activity_count,
    boxplot as plot_activity_boxplot,
    total_duration as plot_activity_duration,
    transitions as plot_activity_transitions,
    density_one_day as plot_activity_density
)

# %%
plot_activity_count(data.df_activities);

# %%
plot_activity_boxplot(data.df_activities);

# %%
plot_activity_duration(data.df_activities);

# %%
plot_activity_transitions(data.df_activities);

# %%
plot_activity_density(data.df_activities);

# %% [markdown]
# # Devices

# %%
from pyadlml.dataset.plot.devices import (
    state_fractions as plot_device_state_fractions,
    state_boxplot as plot_device_state_boxplot,
    state_cross_correlation as plot_device_state_cc,
    event_count as plot_device_event_count,
    event_density_one_day as plot_device_event_density,
    event_raster as plot_device_event_raster,
    inter_event_intervals as plot_device_inter_event_intervals,
    event_cross_correlogram as plot_device_event_cc,    
)

# %%
plot_device_state_fractions(data.df_devices);

# %%
plot_device_state_boxplot(data.df_devices, categories=True);

# %%
plot_device_state_cc(data.df_devices);

# %%
plot_device_inter_event_intervals(data.df_devices);

# %%
plot_device_event_count(data.df_devices);

# %%
plot_device_event_density(data.df_devices);

# %%
plot_device_event_raster(data.df_devices);

# %%
plot_device_event_cc(data.df_devices);

# %% [markdown]
# # Activities vs Devices

# %%
from pyadlml.dataset.plot.act_and_devs import (
    contingency_states as plot_contingency_states,
    contingency_events as plot_contingency_events,
    cross_correlogram as plot_cross_correlogram,
    plot_activities_vs_devices as plot_activities_vs_devices,
    plot_activities_vs_devices_states as plot_activities_vs_devices_states
)

# %%
plot_activities_vs_devices(data.df_devices, data.df_activities);

# %%
plot_activities_vs_devices_states(data.df_devices, data.df_activities);

# %%
plot_contingency_states(data.df_devices, data.df_activities);

# %%
plot_contingency_events(data.df_devices, data.df_activities);

# %%
plot_contingency_events(data.df_devices, data.df_activities, per_state=True);

# %%
plot_cross_correlogram(data.df_devices, data.df_activities);
# Out:
# -------------------------------------------------------
# NameError             Traceback (most recent call last)
# <ipython-input-19-f4ea3ff93817> in <module>
# ----> 1 plot_cross_correlogram(data.df_devices, data.df_activities);
#
# NameError: name 'plot_cross_correlogram' is not defined
