# %%
import sys
sys.path.append("../../")
import pathlib
working_directory = pathlib.Path().absolute()
sys.path.append(str(working_directory))
from pyadlml.dataset import set_data_home, load_act_assist
SUBJECT_ONE_NAME = 'one'
SUBJECT_TWO_NAME = 'two'
SUBJECT_ADMIN_NAME = 'admin'
dataset_dir = str(working_directory) + '/empty_dataset'
data = load_act_assist(dataset_dir,subjects=[SUBJECT_ONE_NAME, SUBJECT_TWO_NAME])

# %%
from pyadlml.dataset.plot.activities import  boxplot_duration, heatmap_transitions, hist_cum_duration, ridge_line, hist_counts

# %%
hist_counts(data.df_activities_one);

# %%
ridge_line(data.df_activities_one, data.lst_activities);

# %%
hist_cum_duration(data.df_activities_one, data.lst_activities);

# %%
heatmap_transitions(data.df_activities_one, data.lst_activities);

# %%
boxplot_duration(data.df_activities_one, data.lst_activities);
# Out:
# ../../pyadlml/dataset/plot/activities.py:127: UserWarning: Data has no positive values, and therefore cannot be log-scaled.
#   ax.set_xscale('log')

# %%
from pyadlml.dataset.plot.devices import hist_counts, heatmap_trigger_one_day, heatmap_trigger_time,\
           hist_on_off, boxplot_on_duration, heatmap_cross_correlation, hist_trigger_time_diff

# %%
hist_counts(data.df_devices, lst_dev=data.lst_devices);

# %%
heatmap_trigger_one_day(data.df_devices, lst_dev=data.lst_devices);
# Out:
# ../../pyadlml/dataset/plot/util.py:159: UserWarning: Attempting to set identical left == right == -0.5 results in singular transformations; automatically expanding.
#   im = ax.imshow(data, **kwargs)

# %%
hist_on_off(data.df_devices, data.lst_devices);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-36f07c6477a8> in <module>
# ----> 1 hist_on_off(data.df_devices, data.lst_devices);
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/plot/devices.py in hist_on_off(df_dev, lst_dev, df_onoff, figsize, color, color_sec, file_path)
#     301
#     302     if df_onoff is None:
# --> 303         df = devices_on_off_stats(df_dev, lst=lst_dev)
#     304     else:
#     305         df = df_onoff
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/stats/devices.py in devices_on_off_stats(df, lst)
#     162     frac_off = 'frac_off'
#     163     if not _is_dev_rep2(df):
# --> 164         df, _ = device_rep1_2_rep2(df.copy(), drop=False)
#     165     df = df.sort_values(START_TIME)
#     166
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/devices.py in device_rep1_2_rep2(df_rep1, drop)
#     105     df = df_rep1.copy().reset_index(drop=True)
#     106     df = df.sort_values(TIME)
# --> 107     df.loc[:,'ones'] = 1
#     108
#     109     rows_changed = 0
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1586                         if any(not l for l in len_non_info_axes):
#    1587                             if not is_list_like_indexer(value):
# -> 1588                                 raise ValueError(
#    1589                                     "cannot set a frame with no "
#    1590                                     "defined index and a scalar"
#
# ValueError: cannot set a frame with no defined index and a scalar

# %%
boxplot_on_duration(data.df_devices, lst_dev=data.lst_devices);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-a9dbe91f8574> in <module>
# ----> 1 boxplot_on_duration(data.df_devices, lst_dev=data.lst_devices);
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/plot/devices.py in boxplot_on_duration(df_dev, lst_dev, figsize, file_path)
#      90     xlabel_top = 'time'
#      91     from pyadlml.dataset.stats.devices import devices_td_on
# ---> 92     df_dev = devices_td_on(df_dev)
#      93
#      94     # select data for each device
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/stats/devices.py in devices_td_on(df)
#     137     time_difference = 'td'
#     138     if not _is_dev_rep2(df):
# --> 139         df, _ = device_rep1_2_rep2(df.copy(), drop=False)
#     140     df[time_difference] = df[END_TIME] - df[START_TIME]
#     141     return df[[DEVICE, time_difference]]
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/devices.py in device_rep1_2_rep2(df_rep1, drop)
#     105     df = df_rep1.copy().reset_index(drop=True)
#     106     df = df.sort_values(TIME)
# --> 107     df.loc[:,'ones'] = 1
#     108
#     109     rows_changed = 0
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 670         iloc._setitem_with_indexer(indexer, value)
#     671
#     672     def _validate_key(self, key, axis: int):
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#    1586                         if any(not l for l in len_non_info_axes):
#    1587                             if not is_list_like_indexer(value):
# -> 1588                                 raise ValueError(
#    1589                                     "cannot set a frame with no "
#    1590                                     "defined index and a scalar"
#
# ValueError: cannot set a frame with no defined index and a scalar

# %%
heatmap_trigger_time(data.df_devices, lst_dev=data.lst_devices);
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-14-d2ddfc1302c3> in <module>
# ----> 1 heatmap_trigger_time(data.df_devices, lst_dev=data.lst_devices);
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/plot/devices.py in heatmap_trigger_time(df_dev, lst_dev, df_tcorr, t_window, figsize, z_scale, cmap, numbers, file_path)
#     190
#     191     if df_tcorr is None:
# --> 192         df = device_tcorr(df_dev, lst_dev=lst_dev, t_window=t_window)
#     193     else:
#     194         df = df_tcorr
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/stats/devices.py in device_tcorr(df, lst_dev, t_window)
#     222         dev_list =  df.device.unique()
#     223
# --> 224     df.iloc[0,3] = pd.Timedelta(0, 's')
#     225     df['cum_sum'] = df['time_diff'].cumsum()
#     226
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     665             key = com.apply_if_callable(key, self.obj)
#     666         indexer = self._get_setitem_indexer(key)
# --> 667         self._has_valid_setitem_indexer(key)
#     668
#     669         iloc = self if self.name == "iloc" else self.obj.iloc
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/pandas/core/indexing.py in _has_valid_setitem_indexer(self, indexer)
#    1392                 elif is_integer(i):
#    1393                     if i >= len(ax):
# -> 1394                         raise IndexError("iloc cannot enlarge its target object")
#    1395                 elif isinstance(i, dict):
#    1396                     raise IndexError("iloc cannot enlarge its target object")
#
# IndexError: iloc cannot enlarge its target object

# %%
hist_trigger_time_diff(data.df_devices);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-778f87af97e6> in <module>
# ----> 1 hist_trigger_time_diff(data.df_devices);
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/plot/devices.py in hist_trigger_time_diff(df_dev, x, n_bins, figsize, color, file_path)
#      40
#      41     # make equal bin size from max to min
# ---> 42     bins = np.logspace(min(np.log10(X)), max(np.log10(X)), n_bins)
#      43
#      44     # make data ready for hist
#
# ValueError: min() arg is an empty sequence

# %%
heatmap_cross_correlation(data.df_devices, lst_dev=data.lst_devices);
# Out:
# /home/chris/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/dask/dataframe/core.py:4338: UserWarning:
# You did not provide metadata, so Dask is running your function on a small dataset to guess output types. It is possible that Dask will guess incorrectly.
# To provide an explicit output types or to silence this message, please provide the `meta=` keyword, as described in the map or apply function that you are using.
#   Before: .apply(func)
#   After:  .apply(func, meta={'time': 'datetime64[ns]', 'td': 'timedelta64[ns]'})
#
#   warnings.warn(meta_warning(meta))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-fa4c323b950d> in <module>
# ----> 1 heatmap_cross_correlation(data.df_devices, lst_dev=data.lst_devices);
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/plot/devices.py in heatmap_cross_correlation(df_dev, lst_dev, df_dur_corr, figsize, numbers, file_path)
#     240
#     241     if df_dur_corr is None:
# --> 242         ct = duration_correlation(df_dev, lst_dev=lst_dev)
#     243     else:
#     244         ct = df_dur_corr
#
# ~/Desktop/code/adlml/pyadlml/pyadlml/dataset/stats/devices.py in duration_correlation(df_dev, lst_dev)
#      60                 #.apply(func, axis=1, meta=create_meta(raw)).drop(columns=['time', 'td']).sum(axis=0)\
#      61
# ---> 62     res = pd.DataFrame(data=np.vstack(df.values), columns=df.index, index=df.index)
#      63     # normalize
#      64     res = res/res.iloc[0,0]
#
# <__array_function__ internals> in vstack(*args, **kwargs)
#
# ~/Desktop/code/adlml/pyadlml/venv_pyadlml/lib/python3.9/site-packages/numpy/core/shape_base.py in vstack(tup)
#     281     if not isinstance(arrs, list):
#     282         arrs = [arrs]
# --> 283     return _nx.concatenate(arrs, 0)
#     284
#     285
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate
